# %% [markdown]
# # Data Handling - Finance Data Project
# # Finance Data Project - Solutions
#
# In this data project I will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
#
# **Note: Maybe the Github repo will not show the `Plotly library` results of the plots creation code, but if you follow the instructions and run the scripts locally they will all be shown correctly to your local machine.**
#
# There will be a focus on bank stocks and seeing how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# *Note: [I'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows me to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**).*
#
# `pip install pandas-datareader`
#
# First I need to start with the proper imports.
#
# ### Importing libraries

# %%
import pandas_datareader.data as web
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# ## Data
#
# You need to get the data using *pandas datareader*. You will get stock information for the following banks:
# * Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# ** Use [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# #### WARNING: make sure to check that the link above works for the latest API. "google" may not always work.

# %% [markdown]
# ### In this case, in order to be safe of the data repo that is right, I use the **'all_banks'** pickle file that is located inside the directory.

# %%
start = datetime.datetime(2006, 1, 1)
end = datetime.datetime(2016, 1, 1)

bank_stocks = pd.read_pickle('all_banks')

# %%
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker             ...        MS                                  WFC  \
# Stock Info    Volume    ...      Open   High    Low  Close   Volume   Open
# Date                    ...
# 2006-01-03   1537660    ...     57.17  58.49  56.74  58.31  5377000  31.60
# 2006-01-04   1871020    ...     58.70  59.28  58.35  58.35  7977800  31.80
# 2006-01-05   1143160    ...     58.55  58.59  58.02  58.51  5778000  31.50
# ...

# %%
BAC = bank_stocks['BAC']
BAC.head()
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700
# 2006-01-04  47.00  47.24  46.45  46.58  17757900
# 2006-01-05  46.58  46.83  46.32  46.64  14970900
# 2006-01-06  46.80  46.91  46.35  46.57  12599800
# 2006-01-09  46.72  46.97  46.36  46.60  15620000

# %% [markdown]
# ####  Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# ## Exploratory Data Analysis
#
# Exploring now the data! Before continuing, I suggest you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).

# %% [markdown]
# #### What is the max Close price for each bank's stock throughout the time period?

# %%
# 1st way
for tick in tickers:
    print(tick + ": " + str(bank_stocks[tick]['Close'].max()))
# Out:
# BAC: 54.9
# C: 564.1
# GS: 247.92
# JPM: 70.08
# MS: 89.3
# WFC: 58.52

# %%
# 2nd way
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %% [markdown]
# #### Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %% [markdown]
# #### You can use pandas `pct_change()` method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.

# %%
for tick in tickers:
    returns[tick+' Return'] = bank_stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %% [markdown]
# #### Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?

# %%
import seaborn as sns
sns.pairplot(data=returns[1:])  # not just 'data=returns', because the index 0 is NaN, and can't be computed

# %% [markdown]
# Background on [Citigroup's Stock Crash available here.](https://en.wikipedia.org/wiki/Citigroup#November_2008.2C_Collapse_.26_US_Government_Intervention_.28part_of_the_Global_Financial_Crisis.29)
#
# You'll also see the enormous crash in value if you take a look a the stock price plot (which we do later in the visualizations.)

# %% [markdown]
# #### Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns.  You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?

# %%
# Worst Drop (4 of them on Inauguration day)
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anything significant happen in that time frame?
#
# [Citigroup had a stock split.](https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=citigroup+stock+2011+may)

# %% [markdown]
# Best Single Day Gain citigroup stock split in May 2011, but also JPM day after inauguration.

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# #### Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?

# %%
returns.std() # Citigroup riskiest
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %% [markdown]
# ## Riskiness of the stock can be measured by Standard Deviation
#
# ### Large Standard Deviation means that stock goes up and down a lot --> stock is risky
# ### Small Standard Deviation means that the price is pretty steady

# %% [markdown]
# #### Which would you classify as the riskiest for the year 2015?
# (Using `.loc` method because the pandas `ix` method is deprecated)

# %%
returns.loc['2015-01-01':'2016-01-01'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# #### Create a distplot using seaborn of the 2015 returns for Morgan Stanley

# %%
dataMS = returns.loc['2015-01-01':'2016-01-01']['MS Return']
sns.distplot(dataMS, bins=100, color='green', hist_kws=dict(edgecolor="k", linewidth=1))
# Out:
# /home/iotlab_user/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Create a distplot using seaborn of the 2008 returns for CitiGroup

# %%
dataC = returns.loc['2008-01-01':'2009-01-01']['C Return']
sns.distplot(dataC, bins=100, color='red', hist_kws=dict(edgecolor="k", linewidth=1))

# %% [markdown]
# ## More Visualization
#
# A lot of this project focuses on visualizations
#
# ### Importing libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# #### Create a line plot showing Close price for each bank for the entire index of time.  (Hint: Try using a for loop, or use .xs to get a cross section of the data.)

# %%
# 1st Method
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick, figsize=(12,4))
plt.legend()

# %%
# 2nd Method
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot()

# %%
# 3rd method with plotly
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div id="2d74acbb-b2ac-4736-83fd-1a1f7ef7adec" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("2d74acbb-b2ac-4736-83fd-1a1f7ef7adec")) {
# ...

# %% [markdown]
# ## Moving Averages
#
# Analyzing the moving averages for these stocks in the year 2008.

# %%
BAC.head()
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700
# 2006-01-04  47.00  47.24  46.45  46.58  17757900
# 2006-01-05  46.58  46.83  46.32  46.64  14970900
# 2006-01-06  46.80  46.91  46.35  46.57  12599800
# 2006-01-09  46.72  46.97  46.36  46.60  15620000

# %% [markdown]
# #### Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008

# %%
plt.figure(figsize=(12,6))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC CLOSE')
plt.legend()

# %% [markdown]
# ####  Create a `heatmap` of the correlation between the stocks Close Price.

# %%
correlationStocks = bank_stocks.xs('Close', axis=1, level='Stock Info').corr()
sns.heatmap(data=correlationStocks, annot=True)

# %% [markdown]
# ####  Use seaborn's `clustermap` to cluster the correlations together

# %%
sns.clustermap(data=correlationStocks, annot=True)

# %%
# heatmap 2nd way with Plotly
correlationStocks.iplot(kind='heatmap', colorscale='rdylbu')
# Out:
# <div id="d85fffe2-6912-43a3-8865-8975fcc2c87b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("d85fffe2-6912-43a3-8865-8975fcc2c87b")) {
# ...

# %% [markdown]
# ###  Relying now on the cufflinks library to create some Technical Analysis plots.

# %%
BAC.head()
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700
# 2006-01-04  47.00  47.24  46.45  46.58  17757900
# 2006-01-05  46.58  46.83  46.32  46.64  14970900
# 2006-01-06  46.80  46.91  46.35  46.57  12599800
# 2006-01-09  46.72  46.97  46.36  46.60  15620000

# %% [markdown]
# #### Use `.iplot(kind='candle)` to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.

# %%
BAC[['Open', 'High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01'].iplot(kind='candle')
# red color means dicreasing, green color means increasing
# Out:
# <div id="f55e0733-bfd9-4afe-92d1-d75916b1fe85" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("f55e0733-bfd9-4afe-92d1-d75916b1fe85")) {
# ...

# %% [markdown]
# #### Use `.ta_plot(study='sma')` to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.
#     'ta' means technical analysis
#     'sma' means Simple Moving Averages

# %%
bank_stocks['MS']['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='sma')
# Out:
# <div id="20e9b261-236e-4b0d-9ba9-255ea9f8bc43" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("20e9b261-236e-4b0d-9ba9-255ea9f8bc43")) {
# ...

# %%
bank_stocks['MS']['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='sma', periods=[13, 21, 55])
# Out:
# <div id="29b417ff-58ca-4d22-9a2e-98bc9a754b1c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("29b417ff-58ca-4d22-9a2e-98bc9a754b1c")) {
# ...

# %% [markdown]
# #### Use `.ta_plot(study='boll')` to create a Bollinger Band Plot for Bank of America for the year 2015.

# %%
bank_stocks['BAC']['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='boll')
# Out:
# <div id="635e5044-d461-4064-ad50-d238c0a23736" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("635e5044-d461-4064-ad50-d238c0a23736")) {
# ...
